# %%
import landlab
import numpy as np

# %matplotlib inline

# %%
x = np.random.rand(10)
y = np.random.rand(10)

imesh = landlab.VoronoiDelaunayGrid(x=x, y=y)
rmesh = landlab.RasterModelGrid(10, 10, dx=20.)
cmesh = landlab.RadialModelGrid(10, dr=20.)

# %%
rmesh.display_grid()

# %%
imesh.display_grid(draw_voronoi=True)

# %%
cmesh.display_grid()
